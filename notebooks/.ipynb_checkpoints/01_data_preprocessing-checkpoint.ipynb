# %%
import pandas as pd

# Load dataset
df = pd.read_csv("../data/Spotify Million Song Dataset_exported.csv")

df.head()
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \nAnd...
# 1  Take it easy with me, please  \nTouch me gentl...
# 2  I'll never know why I had to go  \nWhy I had t...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57650 entries, 0 to 57649
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   artist  57650 non-null  object
#  1   song    57650 non-null  object
#  2   link    57650 non-null  object
#  3   text    57650 non-null  object
# dtypes: object(4)
# memory usage: 1.8+ MB

# %%
df.columns
# Out:
# Index(['artist', 'song', 'link', 'text'], dtype='object')

# %%
df.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
df.sample(5)
# Out:
#                artist                         song  \
# 27481        Children                 Build A Home
# 28082   Cliff Richard              High Class Baby
# 29936    Dolly Parton  Daddy Won't Be Home Anymore
# 38667  Jose Mari Chan                Radio Romance
# 8284        Incognito                 Always There
#
#                                                     link  \
# 27481             /c/children/build+a+home_20590451.html
# 28082     /c/cliff+richard/high+class+baby_20212392.html
# 29936  /d/dolly+parton/daddy+wont+be+home+anymore_201...
# 38667      /j/jose+mari+chan/radio+romance_21063808.html
# 8284             /i/incognito/always+there_20067107.html
#
#                                                     text
# 27481  Deep the cellar, timbers high,  \n(Both hands ...
# 28082  Well you can't be my lovin' baby, you ain't go...
# 29936  As I look around the little house we were so h...
# 38667  The music of love that sings forever is on you...
# 8284   Such a good feeling  \nThat's where I want to ...

# %%
df = df[['artist', 'song', 'text']]
df.head()
# Out:
#   artist                   song  \
# 0   ABBA  Ahe's My Kind Of Girl
# 1   ABBA       Andante, Andante
# 2   ABBA         As Good As New
# 3   ABBA                   Bang
# 4   ABBA       Bang-A-Boomerang
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \nAnd...
# 1  Take it easy with me, please  \nTouch me gentl...
# 2  I'll never know why I had to go  \nWhy I had t...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.dropna(subset=['text'], inplace=True)
df.isnull().sum()
# Out:
# artist    0
# song      0
# text      0
# dtype: int64

# %%
import re

def clean_text(text):
    text = text.lower()                                      # lowercase
    text = re.sub(r'\[.*?\]', '', text)                       # remove [chorus] etc
    text = re.sub(r'https?://\S+|www\.\S+', '', text)         # remove links
    text = re.sub(r'[^a-zA-Z\s]', '', text)                   # keep letters only
    text = re.sub(r'\s+', ' ', text).strip()                  # remove extra spaces
    return text

df['clean_text'] = df['text'].apply(clean_text)
df.head()
# Out:
#   artist                   song  \
# 0   ABBA  Ahe's My Kind Of Girl
# 1   ABBA       Andante, Andante
# 2   ABBA         As Good As New
# 3   ABBA                   Bang
# 4   ABBA       Bang-A-Boomerang
#
#                                                 text  \
# 0  Look at her face, it's a wonderful face  \nAnd...
# 1  Take it easy with me, please  \nTouch me gentl...
# 2  I'll never know why I had to go  \nWhy I had t...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...
#
#                                           clean_text
# 0  look at her face its a wonderful face and it m...
# 1  take it easy with me please touch me gently li...
# 2  ill never know why i had to go why i had to pu...
# 3  making somebody happy is a question of give an...
# 4  making somebody happy is a question of give an...

# %%
import nltk
from nltk.corpus import stopwords

stop = set(stopwords.words('english'))

df['clean_text'] = df['clean_text'].apply(lambda x: " ".join([word for word in x.split() if word not in stop]))
df.head()
# Out:
#   artist                   song  \
# 0   ABBA  Ahe's My Kind Of Girl
# 1   ABBA       Andante, Andante
# 2   ABBA         As Good As New
# 3   ABBA                   Bang
# 4   ABBA       Bang-A-Boomerang
#
#                                                 text  \
# 0  Look at her face, it's a wonderful face  \nAnd...
# 1  Take it easy with me, please  \nTouch me gentl...
# 2  I'll never know why I had to go  \nWhy I had t...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...
#
#                                           clean_text
# 0  look face wonderful face means something speci...
# 1  take easy please touch gently like summer even...
# 2  ill never know go put lousy rotten show boy to...
# 3  making somebody happy question give take learn...
# 4  making somebody happy question give take learn...

# %%
df[['song','artist','clean_text']].sample(5)
# Out:
#                       song          artist  \
# 49607      Highway To Hell      Quiet Riot
# 36714   Wish You Were Here         Incubus
# 28456           Love Twist    Culture Club
# 19570                 Mary       Tori Amos
# 5130   Mansion On The Hill  Emmylou Harris
#
#                                               clean_text
# 49607  living easy living free season ticket oneway r...
# 36714  dig toes sand ocean looks like thousand diamon...
# 28456  footsteps movements finding people clutch forb...
# 19570  everybody wants something everybody want piece...
# 5130   theres place edge town sir risin factories fie...
