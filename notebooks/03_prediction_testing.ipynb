# %%
import sys
import os

# Add project root path to Python import path
sys.path.append(os.path.abspath("../"))
sys.path.append(os.path.abspath("../src"))

# %%
from src.predict import predict_song

lyrics = "living easy living free season ticket on a one way ride"
predict_song(lyrics)
# Out:
#                     song      artist
# 42245        Crazy World  Lucky Dube
# 32283  The Fabolous Life    Fabolous
# 36374  Livin' In A Heart  Ian Hunter
